# %% [markdown]
# # Data Analysis
# ## A Bayesian Tutorial
# ### Second edition (ISBN 978-0-19-856831-5)
# ### By D. S. Sivia, with J. Skilling
# Implementation and testing of ideas from the book
# <img src="images/book_cover.jpeg" width="250"/>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import beta
import torch

import pyro
import pyro.infer
import pyro.optim
import pyro.distributions as dist
from pyro import param
from pyro.poutine import trace
from pyro import condition
from pyro.optim import Adam, ClippedAdam
from pyro.infer import SVI, Trace_ELBO, HMC, MCMC, NUTS
from pyro.contrib.autoguide import AutoDiagonalNormal, AutoMultivariateNormal, AutoContinuous

from torch import tensor
from pprint import pprint




from os.path import join, exists, basename


display('pyro version: {}'.format(pyro.__version__))

pyro.set_rng_seed(101)
# Out:
# 'pyro version: 1.3.0'

# %% [markdown]
# # 2 Parameter estimation I

# %% [markdown]
# ## 2.1 Example 1: is this a fair coin?
# A coin is flipped repeatedly, task is to figure out whether the coin is fair or not. Page 14.

# %% [markdown]
# #### Define function that describes the coin

# %%
def coinflip(headfreq=0.25):
    '''
    Simulates a biased coin.
    headfreq defines the proportion of heads 
    (1 signifies head, 0 signifies tail)
    '''
    return pyro.sample('flip', dist.Bernoulli(headfreq)).item()

# %% [markdown]
# #### Generate data

# %%
# the first four flips are H, H, T, T, as in the book
flip_data = [1.0, 1.0, 0.0, 0.0]
translate_dict = {1.0:'H', 0.0:'T'}

# the rest is random as per the coin
num_flips = 4096 - 4
flip_data += [coinflip() for i in range(num_flips)]
print('Proportion of heads is {:.2f} out of {} flips'.format(flip_data.count(1.0)/num_flips, len(flip_data)))

# convert to tensor
flip_data = tensor(flip_data)
# Out:
# Proportion of heads is 0.25 out of 4096 flips

# %% [markdown]
# #### Define the model

# %%
def model(data):
    '''
    '''    
    # set up the prior as a beta distribution
    alpha0 = 1
    beta0 = 1
    prior = dist.Beta(alpha0, beta0) # could use dist.Uniform(0.0, 1.0) but beta allows me to test non-uniform dists as well
    
    # now sample a head/tail probability (fairness) from this distribution
    f = pyro.sample('latent_fairness', prior)
    
    # For each of the observations, let's draw a sample from our distribution.
    with pyro.plate('observed_data'):
        pyro.sample('obs', dist.Bernoulli(f), obs=data)

# %% [markdown]
# #### Run the model

# %%
# %%time

# number of flips to evaluate
num_flips = [0, 1, 2, 
            3, 4, 8,
            16, 32, 64,
            128, 256, 512,
            1024, 2048, 4096]

results = []
for flips in num_flips:
    
    # Clear named parameters so that runs don't interfere
    pyro.clear_param_store()

    # Using NUTS here as it seems to perform better than HMC
    my_kernel = NUTS(model)

    # 50 000 seems to strike a good balance between computation time and accuracy
    my_mcmc = MCMC(my_kernel,
                   num_samples=50000,
                   warmup_steps=100)

    # Only use the first datapoints, as specified by flips
    # to show how belief is updated as we see more and more data
    my_mcmc.run(flip_data[:flips])
    
    # store results for later plotting
    results.append(my_mcmc.get_samples()['latent_fairness'].numpy())
# Out:
# CPU times: user 7 µs, sys: 1 µs, total: 8 µs
# Wall time: 13.6 µs

# %%
# make a plot of the posterior probability (similar to figure 2.1 in the book)
fig = plt.figure(figsize=(9, 12))


for i in range(0, 15):

    ax = fig.add_subplot(5, 3, i+1)

    plt.hist(results[i], bins=100, range=[0.0, 1.0], 
             histtype='stepfilled', alpha=0.3, color='steelblue', edgecolor='none')

    plt.xlim((0.0, 1.0))
    plt.xticks(np.arange(0, 1.1, step=0.5))
    plt.xlabel("Bias-weighting for heads H")

    plt.yticks([])
    plt.ylabel("prob(H|{data},I)")

    # indicate number of flips
    plt.text(0.95, 0.9, '{}'.format(num_flips[i]), 
             horizontalalignment='right',
            transform=ax.transAxes)
    
    # write out whether heads or tails in the first four flips
    if i in [1, 2, 3, 4]:
        plt.text(0.05, 0.9, '{}'.format(translate_dict[int(flip_data[i-1])]), # need -1 here as the first flip_data entry is is zero flips
                 horizontalalignment='left',
                transform=ax.transAxes)
    
plt.tight_layout()
plt.show()

# %%
# get summary statistics of the last MCMC run (4096 coin flips)
my_mcmc.summary(prob=0.90)
# Out:
#                        mean       std    median      5.0%     95.0%     n_eff     r_hat
#   latent_fairness      0.25      0.01      0.25      0.24      0.26  15971.06      1.00
#
# Number of divergences: 0

# %% [markdown]
# ### Conclusions
# xyz

# %% [markdown]
# ### Try the same computation using SVI
# The MCMC approach is nice but takes a long time to compute. Let's try another way.

# %%
def model_guide(data):
    '''
    '''
    # set up the prior as a beta distribution
    alpha = param('alpha', tensor(1.0), constraint=dist.constraints.positive)
    beta = param('beta', tensor(1.0), constraint=dist.constraints.positive)
    prior = dist.Beta(alpha, beta) # could use dist.Uniform(0.0, 1.0) but beta allows me to test non-uniform dists as well
    
    # now sample a head/tail probability (fairness) from this distribution
    f = pyro.sample('latent_fairness', prior)

# %% [markdown]
# #### Define the guide

# %% [markdown]
# #### Update the model with data

# %%
# %%time


# Run optimization
results = []

for flips in num_flips:
    
    # Clear all the parameter store
    pyro.clear_param_store()

    # Define the SVI algorithm.
    my_svi = SVI(model=model,
                 guide=model_guide,
                 optim=Adam({"lr": 0.1}),
                 loss=Trace_ELBO())
    
    param_vals = []
    optimization_steps = 10000
    for i in range(optimization_steps):

        loss = my_svi.step(flip_data[:flips])

        # store values for inspection later
        param_vals.append({k: param(k).item() for k in ['alpha', 'beta']})
        param_vals[-1]['loss'] = loss

        if (i % 100 == 0):
            print(f'iter: {i}, loss: {round(loss, 2)}', end="\r")

    results.append(param_vals)
        
    # plot the parameters and the loss
    pd.DataFrame(param_vals).plot(subplots=True, figsize=(10,7), title='{} flips'.format(flips))
    plt.xlabel('Steps')

    print(f'"alpha" is {pyro.param("alpha")} after {flips} flips')
    print(f'"beta" is {pyro.param("beta")} after {flips} flips')
# Out:
# "alpha" is 1.18514883518219 after 0 flips
# "beta" is 0.931772768497467 after 0 flips
# "alpha" is 2.2387452125549316 after 1 flips
# "beta" is 0.7334960699081421 after 1 flips
# "alpha" is 3.3113856315612793 after 2 flips
# "beta" is 1.2709306478500366 after 2 flips
# "alpha" is 3.7741646766662598 after 3 flips
# "beta" is 2.221693515777588 after 3 flips
# "alpha" is 4.074458122253418 after 4 flips
# "beta" is 3.0264272689819336 after 4 flips
# "alpha" is 6.423203945159912 after 8 flips
# "beta" is 4.655738353729248 after 8 flips
# "alpha" is 8.17922592163086 after 16 flips
# "beta" is 10.62898063659668 after 16 flips
# "alpha" is 11.695985794067383 after 32 flips
# "beta" is 31.812101364135742 after 32 flips
# "alpha" is 16.727977752685547 after 64 flips
# "beta" is 51.94319534301758 after 64 flips
# "alpha" is 26.454591751098633 after 128 flips
# "beta" is 86.5483627319336 after 128 flips
# "alpha" is 65.85611724853516 after 256 flips
# "beta" is 203.4288330078125 after 256 flips
# "alpha" is 131.03843688964844 after 512 flips
# "beta" is 364.70135498046875 after 512 flips
# "alpha" is 275.3099365234375 after 1024 flips
# "beta" is 750.0537109375 after 1024 flips
# "alpha" is 457.9143981933594 after 2048 flips
# "beta" is 1580.2537841796875 after 2048 flips
# "alpha" is 1046.8209228515625 after 4096 flips
# "beta" is 2982.29150390625 after 4096 flips
# CPU times: user 5min 28s, sys: 3.89 s, total: 5min 32s
# Wall time: 5min 32s

# %%
fig = plt.figure(figsize=(9, 12))


for i in range(0, 15):

    ax = fig.add_subplot(5, 3, i+1)

    # take the mean of the last 100 steps (because the variables bounce around)
    sum_over = 100
    a = sum([results[i][-j]['alpha'] for j in range(1, sum_over+1)]) / sum_over
    b = sum([results[i][-j]['beta'] for j in range(1, sum_over+1)]) / sum_over
    x = np.arange(0, 1.0, 0.01)
    y = beta.pdf(x, a, b, scale=1.0, loc=0.0)
    plt.plot(x, y)

    plt.xlim((0.0, 1.0))
    plt.xticks(np.arange(0, 1.1, step=0.5))
    plt.xlabel("Bias-weighting for heads H")

    plt.yticks([])
    plt.ylabel("prob(H|{data},I)")

    # indicate number of flips
    plt.text(0.95, 0.9, '{}'.format(num_flips[i]), 
             horizontalalignment='right',
            transform=ax.transAxes)
    
    # write out whether heads or tails in the first four flips
    if i in [1, 2, 3, 4]:
        plt.text(0.05, 0.9, '{}'.format(translate_dict[int(flip_data[i-1])]), # need -1 here as the first flip_data entry is is zero flips
                 horizontalalignment='left',
                transform=ax.transAxes)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusion:
# much faster! 5 min vs 60
# only works for well-behaved distributions, does not work for multimodal
# hard to tell progress from loss measure

# %% [markdown]
# ## 2.4 Example 3: the lighthouse problem
# . Page 29.
#
# <img src="images/figure_2.7.png" width="550"/>
#
# Figure 2.7, page 30.

# %%
# First eight datapoints as indicated in figure 2.9 on page 33. 
# Data extracted from book figure using WebPlotDigitizer (https://apps.automeris.io)


data = tensor([4.7, 0.4, -1.8, 0.1, 1.0, 1.1, 1.3, 2.2])


def lighthouse():
    '''
    '''
    pass

# %% [markdown]
# # 3 Parameter estimation II

# %% [markdown]
# ## 3.1 Example 4: amplitude of a signal in the presence of background
# xyz. Page 35.
#
# <img src="images/figure_3.1.png" width="550"/>
#
# Figure 3.1, page 35.
